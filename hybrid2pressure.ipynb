# %%
import argparse 
import ast

import cf_xarray
#import cftime
import geocat.comp as gcomp
#import holoviews as hv
#import hvplot
#import hvplot.xarray
#import intake
import numpy as np
#import pop_tools
import xarray as xr
import xesmf as xe

#from distributed import Client
#from ncar_jobqueue import NCARCluster
#from pop_tools.grid import _compute_corners

import logging 
import netCDF4 as nc
from numba import jit

# %% [markdown]
# ## Questions:
# Do certain variables still need to be reversed?
# Is surface geopotential and lowest layer geopotential treated the same here?
# Does geocat's interp function work across time?
# Is it better to build an atomic function and use appy_ufunc or build in vectorization?
# If you use numpy functions on xarray dataarrays, does xarray intercept the function to correct the dimensions?
#
# TO DO:
# Implement weight reuse
# Implement pressure levels
# Fix wrong standard name for SST
# Add hooks for user-defined reference pressure?
# Add hook to keep metadata
# Fix up METGRID default value
# Implement unit converter (pint) or unit checker
# NOTES:
# Created a branch for a version that works on cf-compliant data

# %%
#Command line option handling ----------------------------------------------------------------------------------
parser = argparse.ArgumentParser()  
logging.basicConfig(level=logging.DEBUG)
current_log_level = logging.getLogger().getEffectiveLevel() 

parser.add_argument('CASE',type=str, help='One of the following IPCC Climate Scenarios: 20THC/RCP85/RCP60/RCP45')
parser.add_argument('--o',type=str,help='Output directory path')
parser.add_argument('--mode','-m',type=str,help='Set logging mode: DEBUG/INFO/WARNING/ERROR/CRITICAL')
parser.add_argument('--plev',type=str, help="File name of desired output pressure levels")
parser.add_argument('--weights',type=str, help="File name if reusing regridding weights")

if current_log_level != 10: 
    args = parser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h] [--o O] [--mode MODE] [--plev PLEV]
#                              [--weights WEIGHTS]
#                              CASE
# ipykernel_launcher.py: error: the following arguments are required: CASE
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
#File Handling ----------------------------------------------------------------------------------

logging.info("Opening data files...")

in_ta = xr.open_dataset("atmos_ta.nc")         # 6-hourly 3-d T
in_ua = xr.open_dataset("atmos_ua.nc")         # 6-hourly 3-d U
in_va = xr.open_dataset("atmos_va.nc")         # 6-hourly 3-d V
in_hus = xr.open_dataset("atmos_hus.nc")       # 6-hourly 3-d Q
in_ps = xr.open_dataset("atmos_ps.nc")         # 6-hourly surface pressure
in_zsfc = xr.open_dataset("atmos_zsfc.nc")     # static surface geopotential
in_lmask = xr.open_dataset("atmos_lmask.nc")   # static land mask
in_snw = xr.open_dataset("atmos_snw_1.nc")     # monthly SWE
in_mrlsl = xr.open_dataset("atmos_mrlsl_1.nc") # monthly soil moisture
in_ts = xr.open_dataset("atmos_ts_1.nc")       # monthly skin temp
in_tsl = xr.open_dataset("atmos_tsl_1.nc")     # monthly soil temp
in_tos = xr.open_dataset("atmos_tos_1.nc")     # daily SST on pop grid (gaussian)
in_sic = xr.open_dataset("atmos_sic_1.nc")     # daily SEAICE % on POP grid (gaussian)

# %%
#Regrid SST and SEA ICE fields to CESM Atmospheric Domain ----------------------------------------------------------------------------------

logging.info('Converting Parallel Ocean Program data to coordinate system of atmospheric grid...')

SST = in_tos.cf['surface_temperature']
#Create a mask (not needed for interpolating to atmospheric grid, but just in case there are missing values)
#NOTE THAT THIS CF REFERENCE IS WRONG. SST IS THE CORRECT STANDARD NAME WHICH NEEDS TO BE CORRECTED IN THE DATA
in_tos["mask"] = ~SST.cf.isel(time=0).isnull()

#Regrids SST grid to whatever the atmospheric grid is automatically
regrid = xe.Regridder(in_tos, in_ta, method = 'bilinear', periodic=True, unmapped_to_nan=True)
regrid.to_netcdf('weights_gx1v6_latlon.nc') #write out weights for reuse 

regridded_SST = regrid(in_tos)

if current_log_level == 10: 
    print(regridded_SST)
#regridded_SST.to_netcdf('python_regrid.nc')
#
#use some sort of broadcasting or view here to clone to a 6-hrly variable
# Out:
# INFO:root:Converting Parallel Ocean Program data to coordinate system of atmospheric grid...
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/cf_xarray/accessor.py:1772: UserWarning: Variables {'areacello'} not found in object but are referred to in the CF attributes.
#   warnings.warn(
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xesmf/smm.py:130: UserWarning: Input array is not C_CONTIGUOUS. Will affect performance.
#   warnings.warn('Input array is not C_CONTIGUOUS. ' 'Will affect performance.')
# DEBUG:numba.core.byteflow:bytecode dump:
# >          0	NOP(arg=None, lineno=1037)
#            2	LOAD_GLOBAL(arg=0, lineno=1053)
#            4	LOAD_ATTR(arg=1, lineno=1053)
#            6	LOAD_FAST(arg=3, lineno=1053)
#            8	LOAD_DEREF(arg=0, lineno=1053)
#           10	LOAD_CONST(arg=1, lineno=1053)
#           12	CALL_FUNCTION_KW(arg=2, lineno=1053)
#           14	STORE_FAST(arg=4, lineno=1053)
#           16	LOAD_CONST(arg=2, lineno=1054)
#           18	STORE_FAST(arg=5, lineno=1054)
# >         20	LOAD_FAST(arg=5, lineno=1056)
#           22	LOAD_GLOBAL(arg=2, lineno=1056)
#           24	LOAD_FAST(arg=1, lineno=1056)
#           26	CALL_FUNCTION(arg=1, lineno=1056)
#           28	COMPARE_OP(arg=0, lineno=1056)
#           30	POP_JUMP_IF_FALSE(arg=154, lineno=1056)
#           32	LOAD_FAST(arg=0, lineno=1057)
#           34	LOAD_CONST(arg=2, lineno=1057)
#           36	LOAD_FAST(arg=5, lineno=1057)
#           38	BUILD_TUPLE(arg=2, lineno=1057)
#           40	BINARY_SUBSCR(arg=None, lineno=1057)
#           42	STORE_FAST(arg=6, lineno=1057)
#           44	LOAD_FAST(arg=5, lineno=1058)
#           46	STORE_FAST(arg=7, lineno=1058)
#           48	LOAD_GLOBAL(arg=3, lineno=1060)
#           50	LOAD_FAST(arg=3, lineno=1060)
#           52	LOAD_CONST(arg=3, lineno=1060)
#           54	BINARY_SUBSCR(arg=None, lineno=1060)
#           56	CALL_FUNCTION(arg=1, lineno=1060)
#           58	GET_ITER(arg=None, lineno=1060)
# >         60	FOR_ITER(arg=90, lineno=1060)
#           62	STORE_FAST(arg=8, lineno=1060)
#           64	LOAD_FAST(arg=7, lineno=1061)
#           66	STORE_FAST(arg=5, lineno=1061)
# >         68	LOAD_FAST(arg=5, lineno=1062)
#           70	LOAD_GLOBAL(arg=2, lineno=1062)
#           72	LOAD_FAST(arg=1, lineno=1062)
#           74	CALL_FUNCTION(arg=1, lineno=1062)
#           76	COMPARE_OP(arg=0, lineno=1062)
#           78	POP_JUMP_IF_FALSE(arg=60, lineno=1062)
#           80	LOAD_FAST(arg=0, lineno=1062)
#           82	LOAD_CONST(arg=2, lineno=1062)
#           84	LOAD_FAST(arg=5, lineno=1062)
#           86	BUILD_TUPLE(arg=2, lineno=1062)
#           88	BINARY_SUBSCR(arg=None, lineno=1062)
#           90	LOAD_FAST(arg=6, lineno=1062)
#           92	COMPARE_OP(arg=2, lineno=1062)
#           94	POP_JUMP_IF_FALSE(arg=60, lineno=1062)
#           96	LOAD_FAST(arg=4, lineno=1063)
#           98	LOAD_FAST(arg=6, lineno=1063)
#          100	LOAD_FAST(arg=8, lineno=1063)
#          102	BUILD_TUPLE(arg=2, lineno=1063)
#          104	DUP_TOP_TWO(arg=None, lineno=1063)
#          106	BINARY_SUBSCR(arg=None, lineno=1063)
#          108	LOAD_FAST(arg=1, lineno=1063)
#          110	LOAD_FAST(arg=5, lineno=1063)
#          112	BINARY_SUBSCR(arg=None, lineno=1063)
#          114	LOAD_FAST(arg=2, lineno=1063)
#          116	LOAD_FAST(arg=8, lineno=1063)
#          118	LOAD_FAST(arg=0, lineno=1063)
#          120	LOAD_CONST(arg=3, lineno=1063)
#          122	LOAD_FAST(arg=5, lineno=1063)
#          124	BUILD_TUPLE(arg=2, lineno=1063)
#          126	BINARY_SUBSCR(arg=None, lineno=1063)
#          128	BUILD_TUPLE(arg=2, lineno=1063)
#          130	BINARY_SUBSCR(arg=None, lineno=1063)
#          132	BINARY_MULTIPLY(arg=None, lineno=1063)
#          134	INPLACE_ADD(arg=None, lineno=1063)
#          136	ROT_THREE(arg=None, lineno=1063)
#          138	STORE_SUBSCR(arg=None, lineno=1063)
#          140	LOAD_FAST(arg=5, lineno=1064)
#          142	LOAD_CONST(arg=3, lineno=1064)
#          144	INPLACE_ADD(arg=None, lineno=1064)
#          146	STORE_FAST(arg=5, lineno=1064)
#          148	JUMP_ABSOLUTE(arg=68, lineno=1064)
#          150	JUMP_ABSOLUTE(arg=60, lineno=1064)
# >        152	JUMP_ABSOLUTE(arg=20, lineno=1064)
# >        154	LOAD_FAST(arg=4, lineno=1066)
#          156	RETURN_VALUE(arg=None, lineno=1066)
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=0 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=0 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=0, inst=NOP(arg=None, lineno=1037)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=2, inst=LOAD_GLOBAL(arg=0, lineno=1053)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=4, inst=LOAD_ATTR(arg=1, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$2load_global.0']
# DEBUG:numba.core.byteflow:dispatch pc=6, inst=LOAD_FAST(arg=3, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1']
# DEBUG:numba.core.byteflow:dispatch pc=8, inst=LOAD_DEREF(arg=0, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1', '$out_shape6.2']
# DEBUG:numba.core.byteflow:dispatch pc=10, inst=LOAD_CONST(arg=1, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1', '$out_shape6.2', '$8load_deref.3']
# DEBUG:numba.core.byteflow:dispatch pc=12, inst=CALL_FUNCTION_KW(arg=2, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$4load_attr.1', '$out_shape6.2', '$8load_deref.3', '$const10.4']
# DEBUG:numba.core.byteflow:dispatch pc=14, inst=STORE_FAST(arg=4, lineno=1053)
# DEBUG:numba.core.byteflow:stack ['$12call_function_kw.5']
# DEBUG:numba.core.byteflow:dispatch pc=16, inst=LOAD_CONST(arg=2, lineno=1054)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=18, inst=STORE_FAST(arg=5, lineno=1054)
# DEBUG:numba.core.byteflow:stack ['$const16.6']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=20, stack=(), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=20 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=20 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=20, inst=LOAD_FAST(arg=5, lineno=1056)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=22, inst=LOAD_GLOBAL(arg=2, lineno=1056)
# DEBUG:numba.core.byteflow:stack ['$didx120.0']
# DEBUG:numba.core.byteflow:dispatch pc=24, inst=LOAD_FAST(arg=1, lineno=1056)
# DEBUG:numba.core.byteflow:stack ['$didx120.0', '$22load_global.1']
# DEBUG:numba.core.byteflow:dispatch pc=26, inst=CALL_FUNCTION(arg=1, lineno=1056)
# DEBUG:numba.core.byteflow:stack ['$didx120.0', '$22load_global.1', '$data124.2']
# DEBUG:numba.core.byteflow:dispatch pc=28, inst=COMPARE_OP(arg=0, lineno=1056)
# DEBUG:numba.core.byteflow:stack ['$didx120.0', '$26call_function.3']
# DEBUG:numba.core.byteflow:dispatch pc=30, inst=POP_JUMP_IF_FALSE(arg=154, lineno=1056)
# DEBUG:numba.core.byteflow:stack ['$28compare_op.4']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=32, stack=(), blockstack=(), npush=0), Edge(pc=154, stack=(), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=32 nstack_initial=0), State(pc_initial=154 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=32 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=32, inst=LOAD_FAST(arg=0, lineno=1057)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=34, inst=LOAD_CONST(arg=2, lineno=1057)
# DEBUG:numba.core.byteflow:stack ['$coords132.0']
# DEBUG:numba.core.byteflow:dispatch pc=36, inst=LOAD_FAST(arg=5, lineno=1057)
# DEBUG:numba.core.byteflow:stack ['$coords132.0', '$const34.1']
# DEBUG:numba.core.byteflow:dispatch pc=38, inst=BUILD_TUPLE(arg=2, lineno=1057)
# DEBUG:numba.core.byteflow:stack ['$coords132.0', '$const34.1', '$didx136.2']
# DEBUG:numba.core.byteflow:dispatch pc=40, inst=BINARY_SUBSCR(arg=None, lineno=1057)
# DEBUG:numba.core.byteflow:stack ['$coords132.0', '$38build_tuple.3']
# DEBUG:numba.core.byteflow:dispatch pc=42, inst=STORE_FAST(arg=6, lineno=1057)
# DEBUG:numba.core.byteflow:stack ['$40binary_subscr.4']
# DEBUG:numba.core.byteflow:dispatch pc=44, inst=LOAD_FAST(arg=5, lineno=1058)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=46, inst=STORE_FAST(arg=7, lineno=1058)
# DEBUG:numba.core.byteflow:stack ['$didx144.5']
# DEBUG:numba.core.byteflow:dispatch pc=48, inst=LOAD_GLOBAL(arg=3, lineno=1060)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=50, inst=LOAD_FAST(arg=3, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$48load_global.6']
# DEBUG:numba.core.byteflow:dispatch pc=52, inst=LOAD_CONST(arg=3, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$48load_global.6', '$out_shape50.7']
# DEBUG:numba.core.byteflow:dispatch pc=54, inst=BINARY_SUBSCR(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$48load_global.6', '$out_shape50.7', '$const52.8']
# DEBUG:numba.core.byteflow:dispatch pc=56, inst=CALL_FUNCTION(arg=1, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$48load_global.6', '$54binary_subscr.9']
# DEBUG:numba.core.byteflow:dispatch pc=58, inst=GET_ITER(arg=None, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$56call_function.10']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=60, stack=('$58get_iter.11',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=154 nstack_initial=0), State(pc_initial=60 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=154 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=154, inst=LOAD_FAST(arg=4, lineno=1066)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:dispatch pc=156, inst=RETURN_VALUE(arg=None, lineno=1066)
# DEBUG:numba.core.byteflow:stack ['$out154.0']
# DEBUG:numba.core.byteflow:end state. edges=[]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=60 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi60.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=60 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=60, inst=FOR_ITER(arg=90, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$phi60.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=152, stack=(), blockstack=(), npush=0), Edge(pc=62, stack=('$phi60.0', '$60for_iter.2'), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=152 nstack_initial=0), State(pc_initial=62 nstack_initial=2)])
# DEBUG:numba.core.byteflow:stack: []
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=152 nstack_initial=0)
# DEBUG:numba.core.byteflow:dispatch pc=152, inst=JUMP_ABSOLUTE(arg=20, lineno=1064)
# DEBUG:numba.core.byteflow:stack []
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=20, stack=(), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=62 nstack_initial=2), State(pc_initial=20 nstack_initial=0)])
# DEBUG:numba.core.byteflow:stack: ['$phi62.0', '$phi62.1']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=62 nstack_initial=2)
# DEBUG:numba.core.byteflow:dispatch pc=62, inst=STORE_FAST(arg=8, lineno=1060)
# DEBUG:numba.core.byteflow:stack ['$phi62.0', '$phi62.1']
# DEBUG:numba.core.byteflow:dispatch pc=64, inst=LOAD_FAST(arg=7, lineno=1061)
# DEBUG:numba.core.byteflow:stack ['$phi62.0']
# DEBUG:numba.core.byteflow:dispatch pc=66, inst=STORE_FAST(arg=5, lineno=1061)
# DEBUG:numba.core.byteflow:stack ['$phi62.0', '$didx1_curr64.2']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=68, stack=('$phi62.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=20 nstack_initial=0), State(pc_initial=68 nstack_initial=1)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=68 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi68.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=68 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=68, inst=LOAD_FAST(arg=5, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0']
# DEBUG:numba.core.byteflow:dispatch pc=70, inst=LOAD_GLOBAL(arg=2, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$didx168.1']
# DEBUG:numba.core.byteflow:dispatch pc=72, inst=LOAD_FAST(arg=1, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$didx168.1', '$70load_global.2']
# DEBUG:numba.core.byteflow:dispatch pc=74, inst=CALL_FUNCTION(arg=1, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$didx168.1', '$70load_global.2', '$data172.3']
# DEBUG:numba.core.byteflow:dispatch pc=76, inst=COMPARE_OP(arg=0, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$didx168.1', '$74call_function.4']
# DEBUG:numba.core.byteflow:dispatch pc=78, inst=POP_JUMP_IF_FALSE(arg=60, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi68.0', '$76compare_op.5']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=80, stack=('$phi68.0',), blockstack=(), npush=0), Edge(pc=60, stack=('$phi68.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=80 nstack_initial=1), State(pc_initial=60 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi80.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=80 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=80, inst=LOAD_FAST(arg=0, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0']
# DEBUG:numba.core.byteflow:dispatch pc=82, inst=LOAD_CONST(arg=2, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$coords180.1']
# DEBUG:numba.core.byteflow:dispatch pc=84, inst=LOAD_FAST(arg=5, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$coords180.1', '$const82.2']
# DEBUG:numba.core.byteflow:dispatch pc=86, inst=BUILD_TUPLE(arg=2, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$coords180.1', '$const82.2', '$didx184.3']
# DEBUG:numba.core.byteflow:dispatch pc=88, inst=BINARY_SUBSCR(arg=None, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$coords180.1', '$86build_tuple.4']
# DEBUG:numba.core.byteflow:dispatch pc=90, inst=LOAD_FAST(arg=6, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$88binary_subscr.5']
# DEBUG:numba.core.byteflow:dispatch pc=92, inst=COMPARE_OP(arg=2, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$88binary_subscr.5', '$oidx190.6']
# DEBUG:numba.core.byteflow:dispatch pc=94, inst=POP_JUMP_IF_FALSE(arg=60, lineno=1062)
# DEBUG:numba.core.byteflow:stack ['$phi80.0', '$92compare_op.7']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=96, stack=('$phi80.0',), blockstack=(), npush=0), Edge(pc=60, stack=('$phi80.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=60 nstack_initial=1), State(pc_initial=96 nstack_initial=1), State(pc_initial=60 nstack_initial=1)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=96 nstack_initial=1), State(pc_initial=60 nstack_initial=1)])
# DEBUG:numba.core.byteflow:stack: ['$phi96.0']
# DEBUG:numba.core.byteflow:state.pc_initial: State(pc_initial=96 nstack_initial=1)
# DEBUG:numba.core.byteflow:dispatch pc=96, inst=LOAD_FAST(arg=4, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0']
# DEBUG:numba.core.byteflow:dispatch pc=98, inst=LOAD_FAST(arg=6, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1']
# DEBUG:numba.core.byteflow:dispatch pc=100, inst=LOAD_FAST(arg=8, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$oidx198.2']
# DEBUG:numba.core.byteflow:dispatch pc=102, inst=BUILD_TUPLE(arg=2, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$oidx198.2', '$oidx2100.3']
# DEBUG:numba.core.byteflow:dispatch pc=104, inst=DUP_TOP_TWO(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4']
# DEBUG:numba.core.byteflow:dispatch pc=106, inst=BINARY_SUBSCR(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$104dup_top_two.5', '$104dup_top_two.6']
# DEBUG:numba.core.byteflow:dispatch pc=108, inst=LOAD_FAST(arg=1, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7']
# DEBUG:numba.core.byteflow:dispatch pc=110, inst=LOAD_FAST(arg=5, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$data1108.8']
# DEBUG:numba.core.byteflow:dispatch pc=112, inst=BINARY_SUBSCR(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$data1108.8', '$didx1110.9']
# DEBUG:numba.core.byteflow:dispatch pc=114, inst=LOAD_FAST(arg=2, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10']
# DEBUG:numba.core.byteflow:dispatch pc=116, inst=LOAD_FAST(arg=8, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11']
# DEBUG:numba.core.byteflow:dispatch pc=118, inst=LOAD_FAST(arg=0, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12']
# DEBUG:numba.core.byteflow:dispatch pc=120, inst=LOAD_CONST(arg=3, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12', '$coords1118.13']
# DEBUG:numba.core.byteflow:dispatch pc=122, inst=LOAD_FAST(arg=5, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12', '$coords1118.13', '$const120.14']
# DEBUG:numba.core.byteflow:dispatch pc=124, inst=BUILD_TUPLE(arg=2, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12', '$coords1118.13', '$const120.14', '$didx1122.15']
# DEBUG:numba.core.byteflow:dispatch pc=126, inst=BINARY_SUBSCR(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12', '$coords1118.13', '$124build_tuple.16']
# DEBUG:numba.core.byteflow:dispatch pc=128, inst=BUILD_TUPLE(arg=2, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$oidx2116.12', '$126binary_subscr.17']
# DEBUG:numba.core.byteflow:dispatch pc=130, inst=BINARY_SUBSCR(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$array2114.11', '$128build_tuple.18']
# DEBUG:numba.core.byteflow:dispatch pc=132, inst=BINARY_MULTIPLY(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$112binary_subscr.10', '$130binary_subscr.19']
# DEBUG:numba.core.byteflow:dispatch pc=134, inst=INPLACE_ADD(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$106binary_subscr.7', '$132binary_multiply.20']
# DEBUG:numba.core.byteflow:dispatch pc=136, inst=ROT_THREE(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$out96.1', '$102build_tuple.4', '$134inplace_add.21']
# DEBUG:numba.core.byteflow:dispatch pc=138, inst=STORE_SUBSCR(arg=None, lineno=1063)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$134inplace_add.21', '$out96.1', '$102build_tuple.4']
# DEBUG:numba.core.byteflow:dispatch pc=140, inst=LOAD_FAST(arg=5, lineno=1064)
# DEBUG:numba.core.byteflow:stack ['$phi96.0']
# DEBUG:numba.core.byteflow:dispatch pc=142, inst=LOAD_CONST(arg=3, lineno=1064)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$didx1140.22']
# DEBUG:numba.core.byteflow:dispatch pc=144, inst=INPLACE_ADD(arg=None, lineno=1064)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$didx1140.22', '$const142.23']
# DEBUG:numba.core.byteflow:dispatch pc=146, inst=STORE_FAST(arg=5, lineno=1064)
# DEBUG:numba.core.byteflow:stack ['$phi96.0', '$144inplace_add.24']
# DEBUG:numba.core.byteflow:dispatch pc=148, inst=JUMP_ABSOLUTE(arg=68, lineno=1064)
# DEBUG:numba.core.byteflow:stack ['$phi96.0']
# DEBUG:numba.core.byteflow:end state. edges=[Edge(pc=68, stack=('$phi96.0',), blockstack=(), npush=0)]
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=60 nstack_initial=1), State(pc_initial=68 nstack_initial=1)])
# DEBUG:numba.core.byteflow:pending: deque([State(pc_initial=68 nstack_initial=1)])
# DEBUG:numba.core.byteflow:-------------------------Prune PHIs-------------------------
# DEBUG:numba.core.byteflow:Used_phis: defaultdict(<class 'set'>,
#             {State(pc_initial=0 nstack_initial=0): set(),
#              State(pc_initial=20 nstack_initial=0): set(),
#              State(pc_initial=32 nstack_initial=0): set(),
#              State(pc_initial=60 nstack_initial=1): {'$phi60.0'},
#              State(pc_initial=62 nstack_initial=2): {'$phi62.1'},
#              State(pc_initial=68 nstack_initial=1): set(),
#              State(pc_initial=80 nstack_initial=1): set(),
#              State(pc_initial=96 nstack_initial=1): set(),
#              State(pc_initial=152 nstack_initial=0): set(),
#              State(pc_initial=154 nstack_initial=0): set()})
# DEBUG:numba.core.byteflow:defmap: {'$phi60.0': State(pc_initial=32 nstack_initial=0),
#  '$phi62.1': State(pc_initial=60 nstack_initial=1)}
# DEBUG:numba.core.byteflow:phismap: defaultdict(<class 'set'>,
#             {'$phi60.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0)),
#                           ('$phi68.0', State(pc_initial=68 nstack_initial=1)),
#                           ('$phi80.0', State(pc_initial=80 nstack_initial=1))},
#              '$phi62.0': {('$phi60.0', State(pc_initial=60 nstack_initial=1))},
#              '$phi62.1': {('$60for_iter.2',
#                            State(pc_initial=60 nstack_initial=1))},
#              '$phi68.0': {('$phi62.0', State(pc_initial=62 nstack_initial=2)),
#                           ('$phi96.0', State(pc_initial=96 nstack_initial=1))},
#              '$phi80.0': {('$phi68.0', State(pc_initial=68 nstack_initial=1))},
#              '$phi96.0': {('$phi80.0', State(pc_initial=80 nstack_initial=1))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi60.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0)),
#                           ('$phi62.0', State(pc_initial=62 nstack_initial=2)),
#                           ('$phi96.0', State(pc_initial=96 nstack_initial=1))},
#              '$phi62.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0)),
#                           ('$phi62.0', State(pc_initial=62 nstack_initial=2)),
#                           ('$phi96.0', State(pc_initial=96 nstack_initial=1))},
#              '$phi62.1': {('$60for_iter.2',
#                            State(pc_initial=60 nstack_initial=1))},
#              '$phi68.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0)),
#                           ('$phi80.0', State(pc_initial=80 nstack_initial=1))},
#              '$phi80.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0)),
#                           ('$phi80.0', State(pc_initial=80 nstack_initial=1))},
#              '$phi96.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi60.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi62.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi62.1': {('$60for_iter.2',
#                            State(pc_initial=60 nstack_initial=1))},
#              '$phi68.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi80.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi96.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))}})
# DEBUG:numba.core.byteflow:changing phismap: defaultdict(<class 'set'>,
#             {'$phi60.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi62.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi62.1': {('$60for_iter.2',
#                            State(pc_initial=60 nstack_initial=1))},
#              '$phi68.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi80.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))},
#              '$phi96.0': {('$58get_iter.11',
#                            State(pc_initial=32 nstack_initial=0))}})
# DEBUG:numba.core.byteflow:keep phismap: {'$phi60.0': {('$58get_iter.11', State(pc_initial=32 nstack_initial=0))},
#  '$phi62.1': {('$60for_iter.2', State(pc_initial=60 nstack_initial=1))}}
# DEBUG:numba.core.byteflow:new_out: defaultdict(<class 'dict'>,
#             {State(pc_initial=32 nstack_initial=0): {'$phi60.0': '$58get_iter.11'},
#              State(pc_initial=60 nstack_initial=1): {'$phi62.1': '$60for_iter.2'}})
# DEBUG:numba.core.byteflow:----------------------DONE Prune PHIs-----------------------
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=0 nstack_initial=0):
# AdaptBlockInfo(insts=((0, {}), (2, {'res': '$2load_global.0'}), (4, {'item': '$2load_global.0', 'res': '$4load_attr.1'}), (6, {'res': '$out_shape6.2'}), (8, {'res': '$8load_deref.3'}), (10, {'res': '$const10.4'}), (12, {'func': '$4load_attr.1', 'args': ['$out_shape6.2', '$8load_deref.3'], 'names': '$const10.4', 'res': '$12call_function_kw.5'}), (14, {'value': '$12call_function_kw.5'}), (16, {'res': '$const16.6'}), (18, {'value': '$const16.6'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={20: ()})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=20 nstack_initial=0):
# AdaptBlockInfo(insts=((20, {'res': '$didx120.0'}), (22, {'res': '$22load_global.1'}), (24, {'res': '$data124.2'}), (26, {'func': '$22load_global.1', 'args': ['$data124.2'], 'res': '$26call_function.3'}), (28, {'lhs': '$didx120.0', 'rhs': '$26call_function.3', 'res': '$28compare_op.4'}), (30, {'pred': '$28compare_op.4'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={32: (), 154: ()})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=32 nstack_initial=0):
# AdaptBlockInfo(insts=((32, {'res': '$coords132.0'}), (34, {'res': '$const34.1'}), (36, {'res': '$didx136.2'}), (38, {'items': ['$const34.1', '$didx136.2'], 'res': '$38build_tuple.3'}), (40, {'index': '$38build_tuple.3', 'target': '$coords132.0', 'res': '$40binary_subscr.4'}), (42, {'value': '$40binary_subscr.4'}), (44, {'res': '$didx144.5'}), (46, {'value': '$didx144.5'}), (48, {'res': '$48load_global.6'}), (50, {'res': '$out_shape50.7'}), (52, {'res': '$const52.8'}), (54, {'index': '$const52.8', 'target': '$out_shape50.7', 'res': '$54binary_subscr.9'}), (56, {'func': '$48load_global.6', 'args': ['$54binary_subscr.9'], 'res': '$56call_function.10'}), (58, {'value': '$56call_function.10', 'res': '$58get_iter.11'})), outgoing_phis={'$phi60.0': '$58get_iter.11'}, blockstack=(), active_try_block=None, outgoing_edgepushed={60: ('$58get_iter.11',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=60 nstack_initial=1):
# AdaptBlockInfo(insts=((60, {'iterator': '$phi60.0', 'pair': '$60for_iter.1', 'indval': '$60for_iter.2', 'pred': '$60for_iter.3'}),), outgoing_phis={'$phi62.1': '$60for_iter.2'}, blockstack=(), active_try_block=None, outgoing_edgepushed={152: (), 62: ('$phi60.0', '$60for_iter.2')})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=62 nstack_initial=2):
# AdaptBlockInfo(insts=((62, {'value': '$phi62.1'}), (64, {'res': '$didx1_curr64.2'}), (66, {'value': '$didx1_curr64.2'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={68: ('$phi62.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=68 nstack_initial=1):
# AdaptBlockInfo(insts=((68, {'res': '$didx168.1'}), (70, {'res': '$70load_global.2'}), (72, {'res': '$data172.3'}), (74, {'func': '$70load_global.2', 'args': ['$data172.3'], 'res': '$74call_function.4'}), (76, {'lhs': '$didx168.1', 'rhs': '$74call_function.4', 'res': '$76compare_op.5'}), (78, {'pred': '$76compare_op.5'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={80: ('$phi68.0',), 60: ('$phi68.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=80 nstack_initial=1):
# AdaptBlockInfo(insts=((80, {'res': '$coords180.1'}), (82, {'res': '$const82.2'}), (84, {'res': '$didx184.3'}), (86, {'items': ['$const82.2', '$didx184.3'], 'res': '$86build_tuple.4'}), (88, {'index': '$86build_tuple.4', 'target': '$coords180.1', 'res': '$88binary_subscr.5'}), (90, {'res': '$oidx190.6'}), (92, {'lhs': '$88binary_subscr.5', 'rhs': '$oidx190.6', 'res': '$92compare_op.7'}), (94, {'pred': '$92compare_op.7'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={96: ('$phi80.0',), 60: ('$phi80.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=96 nstack_initial=1):
# AdaptBlockInfo(insts=((96, {'res': '$out96.1'}), (98, {'res': '$oidx198.2'}), (100, {'res': '$oidx2100.3'}), (102, {'items': ['$oidx198.2', '$oidx2100.3'], 'res': '$102build_tuple.4'}), (104, {'orig': ['$out96.1', '$102build_tuple.4'], 'duped': ['$104dup_top_two.5', '$104dup_top_two.6']}), (106, {'index': '$104dup_top_two.6', 'target': '$104dup_top_two.5', 'res': '$106binary_subscr.7'}), (108, {'res': '$data1108.8'}), (110, {'res': '$didx1110.9'}), (112, {'index': '$didx1110.9', 'target': '$data1108.8', 'res': '$112binary_subscr.10'}), (114, {'res': '$array2114.11'}), (116, {'res': '$oidx2116.12'}), (118, {'res': '$coords1118.13'}), (120, {'res': '$const120.14'}), (122, {'res': '$didx1122.15'}), (124, {'items': ['$const120.14', '$didx1122.15'], 'res': '$124build_tuple.16'}), (126, {'index': '$124build_tuple.16', 'target': '$coords1118.13', 'res': '$126binary_subscr.17'}), (128, {'items': ['$oidx2116.12', '$126binary_subscr.17'], 'res': '$128build_tuple.18'}), (130, {'index': '$128build_tuple.18', 'target': '$array2114.11', 'res': '$130binary_subscr.19'}), (132, {'lhs': '$112binary_subscr.10', 'rhs': '$130binary_subscr.19', 'res': '$132binary_multiply.20'}), (134, {'lhs': '$106binary_subscr.7', 'rhs': '$132binary_multiply.20', 'res': '$134inplace_add.21'}), (138, {'target': '$out96.1', 'index': '$102build_tuple.4', 'value': '$134inplace_add.21'}), (140, {'res': '$didx1140.22'}), (142, {'res': '$const142.23'}), (144, {'lhs': '$didx1140.22', 'rhs': '$const142.23', 'res': '$144inplace_add.24'}), (146, {'value': '$144inplace_add.24'}), (148, {})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={68: ('$phi96.0',)})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=152 nstack_initial=0):
# AdaptBlockInfo(insts=((152, {}),), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={20: ()})
# DEBUG:numba.core.byteflow:block_infos State(pc_initial=154 nstack_initial=0):
# AdaptBlockInfo(insts=((154, {'res': '$out154.0'}), (156, {'retval': '$out154.0', 'castval': '$156return_value.1'})), outgoing_phis={}, blockstack=(), active_try_block=None, outgoing_edgepushed={})
# DEBUG:numba.core.interpreter:label 0:
#     coords1 = arg(0, name=coords1)           ['coords1']
#     data1 = arg(1, name=data1)               ['data1']
#     array2 = arg(2, name=array2)             ['array2']
#     out_shape = arg(3, name=out_shape)       ['out_shape']
#     $2load_global.0 = global(np: <module 'numpy' from '/glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numpy/__init__.py'>) ['$2load_global.0']
#     $4load_attr.1 = getattr(value=$2load_global.0, attr=zeros) ['$2load_global.0', '$4load_attr.1']
#     $8load_deref.3 = freevar(dtr: float64)   ['$8load_deref.3']
#     out = call $4load_attr.1(out_shape, func=$4load_attr.1, args=[Var(out_shape, _common.py:1037)], kws=[('dtype', Var($8load_deref.3, _common.py:1053))], vararg=None, varkwarg=None, target=None) ['$4load_attr.1', '$8load_deref.3', 'out', 'out_shape']
#     didx1 = const(int, 0)                    ['didx1']
#     jump 20                                  []
# label 20:
#     $22load_global.1 = global(len: <built-in function len>) ['$22load_global.1']
#     $26call_function.3 = call $22load_global.1(data1, func=$22load_global.1, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None) ['$22load_global.1', '$26call_function.3', 'data1']
#     $28compare_op.4 = didx1 < $26call_function.3 ['$26call_function.3', '$28compare_op.4', 'didx1']
#     bool30 = global(bool: <class 'bool'>)    ['bool30']
#     $30pred = call bool30($28compare_op.4, func=bool30, args=(Var($28compare_op.4, _common.py:1056),), kws=(), vararg=None, varkwarg=None, target=None) ['$28compare_op.4', '$30pred', 'bool30']
#     branch $30pred, 32, 154                  ['$30pred']
# label 32:
#     $const34.1 = const(int, 0)               ['$const34.1']
#     $38build_tuple.3 = build_tuple(items=[Var($const34.1, _common.py:1057), Var(didx1, _common.py:1054)]) ['$38build_tuple.3', '$const34.1', 'didx1']
#     oidx1 = getitem(value=coords1, index=$38build_tuple.3, fn=<built-in function getitem>) ['$38build_tuple.3', 'coords1', 'oidx1']
#     didx1_curr = didx1                       ['didx1', 'didx1_curr']
#     $48load_global.6 = global(range: <class 'range'>) ['$48load_global.6']
#     $const52.8 = const(int, 1)               ['$const52.8']
#     $54binary_subscr.9 = getitem(value=out_shape, index=$const52.8, fn=<built-in function getitem>) ['$54binary_subscr.9', '$const52.8', 'out_shape']
#     $56call_function.10 = call $48load_global.6($54binary_subscr.9, func=$48load_global.6, args=[Var($54binary_subscr.9, _common.py:1060)], kws=(), vararg=None, varkwarg=None, target=None) ['$48load_global.6', '$54binary_subscr.9', '$56call_function.10']
#     $58get_iter.11 = getiter(value=$56call_function.10) ['$56call_function.10', '$58get_iter.11']
#     $phi60.0 = $58get_iter.11                ['$58get_iter.11', '$phi60.0']
#     jump 60                                  []
# label 60:
#     $60for_iter.1 = iternext(value=$phi60.0) ['$60for_iter.1', '$phi60.0']
#     $60for_iter.2 = pair_first(value=$60for_iter.1) ['$60for_iter.1', '$60for_iter.2']
#     $60for_iter.3 = pair_second(value=$60for_iter.1) ['$60for_iter.1', '$60for_iter.3']
#     $phi62.1 = $60for_iter.2                 ['$60for_iter.2', '$phi62.1']
#     branch $60for_iter.3, 62, 152            ['$60for_iter.3']
# label 62:
#     oidx2 = $phi62.1                         ['$phi62.1', 'oidx2']
#     didx1 = didx1_curr                       ['didx1', 'didx1_curr']
#     jump 68                                  []
# label 68:
#     $70load_global.2 = global(len: <built-in function len>) ['$70load_global.2']
#     $74call_function.4 = call $70load_global.2(data1, func=$70load_global.2, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None) ['$70load_global.2', '$74call_function.4', 'data1']
#     $76compare_op.5 = didx1 < $74call_function.4 ['$74call_function.4', '$76compare_op.5', 'didx1']
#     bool78 = global(bool: <class 'bool'>)    ['bool78']
#     $78pred = call bool78($76compare_op.5, func=bool78, args=(Var($76compare_op.5, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None) ['$76compare_op.5', '$78pred', 'bool78']
#     branch $78pred, 80, 60                   ['$78pred']
# label 80:
#     $const82.2 = const(int, 0)               ['$const82.2']
#     $86build_tuple.4 = build_tuple(items=[Var($const82.2, _common.py:1062), Var(didx1, _common.py:1054)]) ['$86build_tuple.4', '$const82.2', 'didx1']
#     $88binary_subscr.5 = getitem(value=coords1, index=$86build_tuple.4, fn=<built-in function getitem>) ['$86build_tuple.4', '$88binary_subscr.5', 'coords1']
#     $92compare_op.7 = $88binary_subscr.5 == oidx1 ['$88binary_subscr.5', '$92compare_op.7', 'oidx1']
#     bool94 = global(bool: <class 'bool'>)    ['bool94']
#     $94pred = call bool94($92compare_op.7, func=bool94, args=(Var($92compare_op.7, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None) ['$92compare_op.7', '$94pred', 'bool94']
#     branch $94pred, 96, 60                   ['$94pred']
# label 96:
#     $102build_tuple.4 = build_tuple(items=[Var(oidx1, _common.py:1057), Var(oidx2, _common.py:1060)]) ['$102build_tuple.4', 'oidx1', 'oidx2']
#     $106binary_subscr.7 = getitem(value=out, index=$102build_tuple.4, fn=<built-in function getitem>) ['$102build_tuple.4', '$106binary_subscr.7', 'out']
#     $112binary_subscr.10 = getitem(value=data1, index=didx1, fn=<built-in function getitem>) ['$112binary_subscr.10', 'data1', 'didx1']
#     $const120.14 = const(int, 1)             ['$const120.14']
#     $124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1, _common.py:1054)]) ['$124build_tuple.16', '$const120.14', 'didx1']
#     $126binary_subscr.17 = getitem(value=coords1, index=$124build_tuple.16, fn=<built-in function getitem>) ['$124build_tuple.16', '$126binary_subscr.17', 'coords1']
#     $128build_tuple.18 = build_tuple(items=[Var(oidx2, _common.py:1060), Var($126binary_subscr.17, _common.py:1063)]) ['$126binary_subscr.17', '$128build_tuple.18', 'oidx2']
#     $130binary_subscr.19 = getitem(value=array2, index=$128build_tuple.18, fn=<built-in function getitem>) ['$128build_tuple.18', '$130binary_subscr.19', 'array2']
#     $132binary_multiply.20 = $112binary_subscr.10 * $130binary_subscr.19 ['$112binary_subscr.10', '$130binary_subscr.19', '$132binary_multiply.20']
#     $134inplace_add.21 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$106binary_subscr.7, rhs=$132binary_multiply.20, static_lhs=Undefined, static_rhs=Undefined) ['$106binary_subscr.7', '$132binary_multiply.20', '$134inplace_add.21']
#     out[$102build_tuple.4] = $134inplace_add.21 ['$102build_tuple.4', '$134inplace_add.21', 'out']
#     $const142.23 = const(int, 1)             ['$const142.23']
#     $144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined) ['$144inplace_add.24', '$const142.23', 'didx1']
#     didx1 = $144inplace_add.24               ['$144inplace_add.24', 'didx1']
#     jump 68                                  []
# label 152:
#     jump 20                                  []
# label 154:
#     $156return_value.1 = cast(value=out)     ['$156return_value.1', 'out']
#     return $156return_value.1                ['$156return_value.1']
#
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: coords1 = arg(0, name=coords1)
# DEBUG:numba.core.ssa:on stmt: data1 = arg(1, name=data1)
# DEBUG:numba.core.ssa:on stmt: array2 = arg(2, name=array2)
# DEBUG:numba.core.ssa:on stmt: out_shape = arg(3, name=out_shape)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_attr.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $8load_deref.3 = freevar(dtr: float64)
# DEBUG:numba.core.ssa:on stmt: out = call $4load_attr.1(out_shape, func=$4load_attr.1, args=[Var(out_shape, _common.py:1037)], kws=[('dtype', Var($8load_deref.3, _common.py:1053))], vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: didx1 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 20
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $22load_global.1 = global(len: <built-in function len>)
# DEBUG:numba.core.ssa:on stmt: $26call_function.3 = call $22load_global.1(data1, func=$22load_global.1, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $28compare_op.4 = didx1 < $26call_function.3
# DEBUG:numba.core.ssa:on stmt: bool30 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $30pred = call bool30($28compare_op.4, func=bool30, args=(Var($28compare_op.4, _common.py:1056),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $30pred, 32, 154
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 32
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $const34.1 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $38build_tuple.3 = build_tuple(items=[Var($const34.1, _common.py:1057), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:on stmt: oidx1 = getitem(value=coords1, index=$38build_tuple.3, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: didx1_curr = didx1
# DEBUG:numba.core.ssa:on stmt: $48load_global.6 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const52.8 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $54binary_subscr.9 = static_getitem(value=out_shape, index=1, index_var=$const52.8, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $56call_function.10 = call $48load_global.6($54binary_subscr.9, func=$48load_global.6, args=[Var($54binary_subscr.9, _common.py:1060)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $58get_iter.11 = getiter(value=$56call_function.10)
# DEBUG:numba.core.ssa:on stmt: $phi60.0 = $58get_iter.11
# DEBUG:numba.core.ssa:on stmt: jump 60
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 60
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $60for_iter.1 = iternext(value=$phi60.0)
# DEBUG:numba.core.ssa:on stmt: $60for_iter.2 = pair_first(value=$60for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $60for_iter.3 = pair_second(value=$60for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $phi62.1 = $60for_iter.2
# DEBUG:numba.core.ssa:on stmt: branch $60for_iter.3, 62, 152
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 62
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: oidx2 = $phi62.1
# DEBUG:numba.core.ssa:on stmt: didx1 = didx1_curr
# DEBUG:numba.core.ssa:on stmt: jump 68
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 68
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $70load_global.2 = global(len: <built-in function len>)
# DEBUG:numba.core.ssa:on stmt: $74call_function.4 = call $70load_global.2(data1, func=$70load_global.2, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $76compare_op.5 = didx1 < $74call_function.4
# DEBUG:numba.core.ssa:on stmt: bool78 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $78pred = call bool78($76compare_op.5, func=bool78, args=(Var($76compare_op.5, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $78pred, 80, 155
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 80
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $const82.2 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $86build_tuple.4 = build_tuple(items=[Var($const82.2, _common.py:1062), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.5 = getitem(value=coords1, index=$86build_tuple.4, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $92compare_op.7 = $88binary_subscr.5 == oidx1
# DEBUG:numba.core.ssa:on stmt: bool94 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $94pred = call bool94($92compare_op.7, func=bool94, args=(Var($92compare_op.7, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $94pred, 96, 155
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 96
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $102build_tuple.4 = build_tuple(items=[Var(oidx1, _common.py:1057), Var(oidx2, _common.py:1060)])
# DEBUG:numba.core.ssa:on stmt: $106binary_subscr.7 = getitem(value=out, index=$102build_tuple.4, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $112binary_subscr.10 = getitem(value=data1, index=didx1, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const120.14 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:on stmt: $126binary_subscr.17 = getitem(value=coords1, index=$124build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $128build_tuple.18 = build_tuple(items=[Var(oidx2, _common.py:1060), Var($126binary_subscr.17, _common.py:1063)])
# DEBUG:numba.core.ssa:on stmt: $130binary_subscr.19 = getitem(value=array2, index=$128build_tuple.18, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $132binary_multiply.20 = $112binary_subscr.10 * $130binary_subscr.19
# DEBUG:numba.core.ssa:on stmt: $134inplace_add.21 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$106binary_subscr.7, rhs=$132binary_multiply.20, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: out[$102build_tuple.4] = $134inplace_add.21
# DEBUG:numba.core.ssa:on stmt: $const142.23 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: didx1 = $144inplace_add.24
# DEBUG:numba.core.ssa:on stmt: jump 68
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 152
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 154
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: $156return_value.1 = cast(value=out)
# DEBUG:numba.core.ssa:on stmt: return $156return_value.1
# DEBUG:numba.core.ssa:==== SSA block analysis pass on 155
# DEBUG:numba.core.ssa:Running <numba.core.ssa._GatherDefsHandler object at 0x2b5d57a53e80>
# DEBUG:numba.core.ssa:on stmt: jump 60
# DEBUG:numba.core.ssa:defs defaultdict(<class 'list'>,
#             {'$102build_tuple.4': [<numba.core.ir.Assign object at 0x2b5d57a57640>],
#              '$106binary_subscr.7': [<numba.core.ir.Assign object at 0x2b5d57a579a0>],
#              '$112binary_subscr.10': [<numba.core.ir.Assign object at 0x2b5d57a57d60>],
#              '$124build_tuple.16': [<numba.core.ir.Assign object at 0x2b5d57a5a550>],
#              '$126binary_subscr.17': [<numba.core.ir.Assign object at 0x2b5d57a5a6d0>],
#              '$128build_tuple.18': [<numba.core.ir.Assign object at 0x2b5d57a5a850>],
#              '$130binary_subscr.19': [<numba.core.ir.Assign object at 0x2b5d57a5a9d0>],
#              '$132binary_multiply.20': [<numba.core.ir.Assign object at 0x2b5d57a5ab50>],
#              '$134inplace_add.21': [<numba.core.ir.Assign object at 0x2b5d57a5acd0>],
#              '$144inplace_add.24': [<numba.core.ir.Assign object at 0x2b5d57a5c1f0>],
#              '$156return_value.1': [<numba.core.ir.Assign object at 0x2b5d57a55520>],
#              '$22load_global.1': [<numba.core.ir.Assign object at 0x2b5d57a4f6d0>],
#              '$26call_function.3': [<numba.core.ir.Assign object at 0x2b5d57a4f9d0>],
#              '$28compare_op.4': [<numba.core.ir.Assign object at 0x2b5d57a4fb20>],
# ...
# DEBUG:numba.core.ssa:on stmt: $124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:on stmt: $126binary_subscr.17 = getitem(value=coords1, index=$124build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $128build_tuple.18 = build_tuple(items=[Var(oidx2, _common.py:1060), Var($126binary_subscr.17, _common.py:1063)])
# DEBUG:numba.core.ssa:on stmt: $130binary_subscr.19 = getitem(value=array2, index=$128build_tuple.18, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $132binary_multiply.20 = $112binary_subscr.10 * $130binary_subscr.19
# DEBUG:numba.core.ssa:on stmt: $134inplace_add.21 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$106binary_subscr.7, rhs=$132binary_multiply.20, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: out[$102build_tuple.4] = $134inplace_add.21
# DEBUG:numba.core.ssa:on stmt: $const142.23 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: didx1 = $144inplace_add.24
# DEBUG:numba.core.ssa:replaced with: didx1.2 = $144inplace_add.24
# DEBUG:numba.core.ssa:on stmt: jump 68
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 152
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x2b5d57e30dc0>
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 154
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x2b5d57e30dc0>
# DEBUG:numba.core.ssa:on stmt: $156return_value.1 = cast(value=out)
# DEBUG:numba.core.ssa:on stmt: return $156return_value.1
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 155
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FreshVarHandler object at 0x2b5d57e30dc0>
# DEBUG:numba.core.ssa:on stmt: jump 60
# DEBUG:numba.core.ssa:Replaced assignments: defaultdict(<class 'list'>,
#             {0: [<numba.core.ir.Assign object at 0x2b5d57a0a640>],
#              62: [<numba.core.ir.Assign object at 0x2b5d57f36820>],
#              96: [<numba.core.ir.Assign object at 0x2b5d57f22610>]})
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 0
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: coords1 = arg(0, name=coords1)
# DEBUG:numba.core.ssa:on stmt: data1 = arg(1, name=data1)
# DEBUG:numba.core.ssa:on stmt: array2 = arg(2, name=array2)
# DEBUG:numba.core.ssa:on stmt: out_shape = arg(3, name=out_shape)
# DEBUG:numba.core.ssa:on stmt: $2load_global.0 = global(np: <module 'numpy' from '/glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numpy/__init__.py'>)
# DEBUG:numba.core.ssa:on stmt: $4load_attr.1 = getattr(value=$2load_global.0, attr=zeros)
# DEBUG:numba.core.ssa:on stmt: $8load_deref.3 = freevar(dtr: float64)
# DEBUG:numba.core.ssa:on stmt: out = call $4load_attr.1(out_shape, func=$4load_attr.1, args=[Var(out_shape, _common.py:1037)], kws=[('dtype', Var($8load_deref.3, _common.py:1053))], vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: didx1 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 20
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $22load_global.1 = global(len: <built-in function len>)
# DEBUG:numba.core.ssa:on stmt: $26call_function.3 = call $22load_global.1(data1, func=$22load_global.1, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $28compare_op.4 = didx1 < $26call_function.3
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$28compare_op.4 = didx1 < $26call_function.3
# DEBUG:numba.core.ssa:find_def_from_top label 20
# DEBUG:numba.core.ssa:insert phi node didx1.3 = phi(incoming_values=[], incoming_blocks=[]) at 20
# DEBUG:numba.core.ssa:find_def_from_bottom label 0
# DEBUG:numba.core.ssa:incoming_def didx1 = const(int, 0)
# DEBUG:numba.core.ssa:find_def_from_bottom label 152
# DEBUG:numba.core.ssa:find_def_from_top label 152
# DEBUG:numba.core.ssa:idom 60 from label 152
# DEBUG:numba.core.ssa:find_def_from_bottom label 60
# DEBUG:numba.core.ssa:find_def_from_top label 60
# DEBUG:numba.core.ssa:insert phi node didx1.4 = phi(incoming_values=[], incoming_blocks=[]) at 60
# DEBUG:numba.core.ssa:find_def_from_bottom label 32
# DEBUG:numba.core.ssa:find_def_from_top label 32
# DEBUG:numba.core.ssa:idom 20 from label 32
# DEBUG:numba.core.ssa:find_def_from_bottom label 20
# DEBUG:numba.core.ssa:incoming_def didx1.3 = phi(incoming_values=[Var(didx1, _common.py:1054)], incoming_blocks=[0])
# DEBUG:numba.core.ssa:find_def_from_bottom label 155
# DEBUG:numba.core.ssa:find_def_from_top label 155
# DEBUG:numba.core.ssa:idom 68 from label 155
# DEBUG:numba.core.ssa:find_def_from_bottom label 68
# DEBUG:numba.core.ssa:find_def_from_top label 68
# DEBUG:numba.core.ssa:insert phi node didx1.5 = phi(incoming_values=[], incoming_blocks=[]) at 68
# DEBUG:numba.core.ssa:find_def_from_bottom label 96
# DEBUG:numba.core.ssa:incoming_def didx1.2 = $144inplace_add.24
# DEBUG:numba.core.ssa:find_def_from_bottom label 62
# DEBUG:numba.core.ssa:incoming_def didx1.1 = didx1_curr
# DEBUG:numba.core.ssa:incoming_def didx1.5 = phi(incoming_values=[Var(didx1.2, _common.py:1064), Var(didx1.1, _common.py:1061)], incoming_blocks=[96, 62])
# DEBUG:numba.core.ssa:incoming_def didx1.4 = phi(incoming_values=[Var(didx1.3, _common.py:1056), Var(didx1.5, _common.py:1056)], incoming_blocks=[32, 155])
# DEBUG:numba.core.ssa:replaced with: $28compare_op.4 = didx1.3 < $26call_function.3
# DEBUG:numba.core.ssa:on stmt: bool30 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $30pred = call bool30($28compare_op.4, func=bool30, args=(Var($28compare_op.4, _common.py:1056),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $30pred, 32, 154
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 32
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $const34.1 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $38build_tuple.3 = build_tuple(items=[Var($const34.1, _common.py:1057), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$38build_tuple.3 = build_tuple(items=[Var($const34.1, _common.py:1057), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def_from_top label 32
# DEBUG:numba.core.ssa:idom 20 from label 32
# DEBUG:numba.core.ssa:find_def_from_bottom label 20
# DEBUG:numba.core.ssa:replaced with: $38build_tuple.3 = build_tuple(items=[Var($const34.1, _common.py:1057), Var(didx1.3, _common.py:1056)])
# DEBUG:numba.core.ssa:on stmt: oidx1 = getitem(value=coords1, index=$38build_tuple.3, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: didx1_curr = didx1
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=didx1_curr = didx1
# DEBUG:numba.core.ssa:find_def_from_top label 32
# DEBUG:numba.core.ssa:idom 20 from label 32
# DEBUG:numba.core.ssa:find_def_from_bottom label 20
# DEBUG:numba.core.ssa:replaced with: didx1_curr = didx1.3
# DEBUG:numba.core.ssa:on stmt: $48load_global.6 = global(range: <class 'range'>)
# DEBUG:numba.core.ssa:on stmt: $const52.8 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $54binary_subscr.9 = static_getitem(value=out_shape, index=1, index_var=$const52.8, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $56call_function.10 = call $48load_global.6($54binary_subscr.9, func=$48load_global.6, args=[Var($54binary_subscr.9, _common.py:1060)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $58get_iter.11 = getiter(value=$56call_function.10)
# DEBUG:numba.core.ssa:on stmt: $phi60.0 = $58get_iter.11
# DEBUG:numba.core.ssa:on stmt: jump 60
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 60
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $60for_iter.1 = iternext(value=$phi60.0)
# DEBUG:numba.core.ssa:on stmt: $60for_iter.2 = pair_first(value=$60for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $60for_iter.3 = pair_second(value=$60for_iter.1)
# DEBUG:numba.core.ssa:on stmt: $phi62.1 = $60for_iter.2
# DEBUG:numba.core.ssa:on stmt: branch $60for_iter.3, 62, 152
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 62
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: oidx2 = $phi62.1
# DEBUG:numba.core.ssa:on stmt: didx1.1 = didx1_curr
# DEBUG:numba.core.ssa:on stmt: jump 68
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 68
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $70load_global.2 = global(len: <built-in function len>)
# DEBUG:numba.core.ssa:on stmt: $74call_function.4 = call $70load_global.2(data1, func=$70load_global.2, args=[Var(data1, _common.py:1037)], kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: $76compare_op.5 = didx1 < $74call_function.4
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$76compare_op.5 = didx1 < $74call_function.4
# DEBUG:numba.core.ssa:replaced with: $76compare_op.5 = didx1.5 < $74call_function.4
# DEBUG:numba.core.ssa:on stmt: bool78 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $78pred = call bool78($76compare_op.5, func=bool78, args=(Var($76compare_op.5, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $78pred, 80, 155
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 80
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $const82.2 = const(int, 0)
# DEBUG:numba.core.ssa:on stmt: $86build_tuple.4 = build_tuple(items=[Var($const82.2, _common.py:1062), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$86build_tuple.4 = build_tuple(items=[Var($const82.2, _common.py:1062), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def_from_top label 80
# DEBUG:numba.core.ssa:idom 68 from label 80
# DEBUG:numba.core.ssa:find_def_from_bottom label 68
# DEBUG:numba.core.ssa:replaced with: $86build_tuple.4 = build_tuple(items=[Var($const82.2, _common.py:1062), Var(didx1.5, _common.py:1056)])
# DEBUG:numba.core.ssa:on stmt: $88binary_subscr.5 = getitem(value=coords1, index=$86build_tuple.4, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $92compare_op.7 = $88binary_subscr.5 == oidx1
# DEBUG:numba.core.ssa:on stmt: bool94 = global(bool: <class 'bool'>)
# DEBUG:numba.core.ssa:on stmt: $94pred = call bool94($92compare_op.7, func=bool94, args=(Var($92compare_op.7, _common.py:1062),), kws=(), vararg=None, varkwarg=None, target=None)
# DEBUG:numba.core.ssa:on stmt: branch $94pred, 96, 155
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 96
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $102build_tuple.4 = build_tuple(items=[Var(oidx1, _common.py:1057), Var(oidx2, _common.py:1060)])
# DEBUG:numba.core.ssa:on stmt: $106binary_subscr.7 = getitem(value=out, index=$102build_tuple.4, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $112binary_subscr.10 = getitem(value=data1, index=didx1, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$112binary_subscr.10 = getitem(value=data1, index=didx1, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:find_def_from_top label 96
# DEBUG:numba.core.ssa:idom 80 from label 96
# DEBUG:numba.core.ssa:find_def_from_bottom label 80
# DEBUG:numba.core.ssa:find_def_from_top label 80
# DEBUG:numba.core.ssa:idom 68 from label 80
# DEBUG:numba.core.ssa:find_def_from_bottom label 68
# DEBUG:numba.core.ssa:replaced with: $112binary_subscr.10 = getitem(value=data1, index=didx1.5, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $const120.14 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1, _common.py:1054)])
# DEBUG:numba.core.ssa:find_def_from_top label 96
# DEBUG:numba.core.ssa:idom 80 from label 96
# DEBUG:numba.core.ssa:find_def_from_bottom label 80
# DEBUG:numba.core.ssa:find_def_from_top label 80
# DEBUG:numba.core.ssa:idom 68 from label 80
# DEBUG:numba.core.ssa:find_def_from_bottom label 68
# DEBUG:numba.core.ssa:replaced with: $124build_tuple.16 = build_tuple(items=[Var($const120.14, _common.py:1063), Var(didx1.5, _common.py:1056)])
# DEBUG:numba.core.ssa:on stmt: $126binary_subscr.17 = getitem(value=coords1, index=$124build_tuple.16, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $128build_tuple.18 = build_tuple(items=[Var(oidx2, _common.py:1060), Var($126binary_subscr.17, _common.py:1063)])
# DEBUG:numba.core.ssa:on stmt: $130binary_subscr.19 = getitem(value=array2, index=$128build_tuple.18, fn=<built-in function getitem>)
# DEBUG:numba.core.ssa:on stmt: $132binary_multiply.20 = $112binary_subscr.10 * $130binary_subscr.19
# DEBUG:numba.core.ssa:on stmt: $134inplace_add.21 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=$106binary_subscr.7, rhs=$132binary_multiply.20, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: out[$102build_tuple.4] = $134inplace_add.21
# DEBUG:numba.core.ssa:on stmt: $const142.23 = const(int, 1)
# DEBUG:numba.core.ssa:on stmt: $144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:find_def var='didx1' stmt=$144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:find_def_from_top label 96
# DEBUG:numba.core.ssa:idom 80 from label 96
# DEBUG:numba.core.ssa:find_def_from_bottom label 80
# DEBUG:numba.core.ssa:find_def_from_top label 80
# DEBUG:numba.core.ssa:idom 68 from label 80
# DEBUG:numba.core.ssa:find_def_from_bottom label 68
# DEBUG:numba.core.ssa:replaced with: $144inplace_add.24 = inplace_binop(fn=<built-in function iadd>, immutable_fn=<built-in function add>, lhs=didx1.5, rhs=$const142.23, static_lhs=Undefined, static_rhs=Undefined)
# DEBUG:numba.core.ssa:on stmt: didx1.2 = $144inplace_add.24
# DEBUG:numba.core.ssa:on stmt: jump 68
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 152
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: jump 20
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 154
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: $156return_value.1 = cast(value=out)
# DEBUG:numba.core.ssa:on stmt: return $156return_value.1
# DEBUG:numba.core.ssa:==== SSA block rewrite pass on 155
# DEBUG:numba.core.ssa:Running <numba.core.ssa._FixSSAVars object at 0x2b5d57f228e0>
# DEBUG:numba.core.ssa:on stmt: jump 60
# <xarray.Dataset>
# Dimensions:   (vertices: 4, lat: 192, lon: 288, time: 92)
# Coordinates:
#   * time      (time) object 2006-10-01 12:00:00 ... 2006-12-31 12:00:00
#   * lat       (lat) float64 -90.0 -89.06 -88.12 -87.17 ... 88.12 89.06 90.0
#   * lon       (lon) float64 0.0 1.25 2.5 3.75 5.0 ... 355.0 356.2 357.5 358.8
# Dimensions without coordinates: vertices
# Data variables:
#     lon_bnds  (vertices, lat, lon) float32 nan nan nan nan ... 248.7 248.7 248.7
#     lat_bnds  (vertices, lat, lon) float32 nan nan nan nan ... 89.65 89.65 89.65
#     tos       (time, lat, lon) float32 nan nan nan nan ... 271.3 271.3 271.3
#     mask      (lat, lon) bool True True True True True ... True True True True
# Attributes:
#     regrid_method:  bilinear

# %%
#Prepare Variables for Interpolation ----------------------------------------------------------------------------------

hyam = in_ta.cf['hyam'] 
hybm = in_ta.cf['hybm']
hyai = in_ta.cf['hyai']
hybi = in_ta.cf['hybi']

surf_pressure = in_ps.cf['PS']

phi_surf = in_zsfc['PHIS']
phi_surf.coords['lat'] = surf_pressure.coords['lat']
phi_surf.coords['lon'] = surf_pressure.coords['lon']
temp = in_ta["T"]

# %% [markdown]
# Check that this is correct - it seems like the coordinate system is somewhat reversed.

# %%
# %%timeit -r 10

#need assertion that missing values are correct 
@jit 
def pressure_on_hybrid_ccm(pressure_surf : xr.DataArray, hyam, hybm, ref_pressure : xr.DataArray =  100000): 
    
    assert 'positive' in hyam.cf['Z'].attrs; "CF Standard requires that non-pressure data has an assigned direction in its vertical coordinate"
    assert 'positive' in hybm.cf['Z'].attrs; "CF Standard requires that non-pressure data has an assigned direction in its vertical coordinate"
    
    #since xarray defaults to nan's for missing values, we can rely on xarray to take care of missing values
    return hyam*ref_pressure + hybm*pressure_surf 
    

P_hybrid = pressure_on_hybrid_ccm(surf_pressure,hyam,hybm)
# Out:
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# <magic-timeit>:3: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
# <magic-timeit>:2: NumbaWarning:
# Compilation is falling back to object mode WITH looplifting enabled because Function "pressure_on_hybrid_ccm" failed type inference due to: non-precise type pyobject
# During: typing of argument at <magic-timeit> (2)
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:151: NumbaWarning: Function "pressure_on_hybrid_ccm" was compiled in object mode without forceobj=True.
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaWarning(warn_msg,
# /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/numba/core/object_mode_passes.py:161: NumbaDeprecationWarning:
# Fall-back from the nopython compilation path to the object mode compilation path has been detected. This is deprecated behaviour that will be removed in Numba 0.59.0.
#
# For more information visit https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit
#
# File "<magic-timeit>", line 2:
# <source missing, REPL/exec in use?>
#
#   warnings.warn(errors.NumbaDeprecationWarning(msg,
# 4.6 s ± 297 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %%
ncl_P_hybrid = xr.open_dataarray('ncl_P_hybrid.nc')
ncl_P_hybrid.coords['time'] = P_hybrid.coords['time']
ncl_P_hybrid.coords['lev'] = P_hybrid.coords['lev']
ncl_P_hybrid.coords['lat'] = P_hybrid.coords['lat']
ncl_P_hybrid.coords['lon'] = P_hybrid.coords['lon']
P_hybrid - ncl_P_hybrid

# %%
def psl_ecmwf(temp_bottom: xr.DataArray, phi_surf: xr.DataArray, pressure_surf: xr.DataArray, pressure_bot: xr.DataArray): 
    #Based on the NCAR Technical Note "Vertical Interpolation and Truncation of Model-Coordinate Data"
    #By Trenberth, Berry, Buja; Dec 1993 
    #temp_surf = T_*, temp_bottom = T_NL, pressure_surf = p_s, pressure_bot = p_NL, phi_surf = \phi_s

    LAPSE_RATE = 0.0065     #Kelvin per meter
    GRAV_CONST = 9.80616    #Meters per second per second
    SPEC_GAS_CONST = 287.04 #Joules per kilogram per Kelvin

    ALPHA_0 = LAPSE_RATE*SPEC_GAS_CONST/GRAV_CONST
    
    phi_surf_expanded = phi_surf.broadcast_like(pressure_surf)
    temp_surf = temp_bottom*(1 + ALPHA_0*(pressure_surf/pressure_bot - 1)) #3b.5
    temp_bot_lapse = temp_surf + LAPSE_RATE*phi_surf/GRAV_CONST #denoted T_0 in doc, 3b.13

    is_near_zero = np.full_like(pressure_surf,False,dtype=bool)
    is_hot_low = np.full_like(pressure_surf,False,dtype=bool)
    is_hot_high = np.full_like(pressure_surf,False,dtype=bool)
    is_mild_high = np.full_like(pressure_surf,False,dtype=bool)
    is_cold_low = np.full_like(pressure_surf,False,dtype=bool)
    is_cold_high = np.full_like(pressure_surf,False,dtype=bool)

    is_near_zero =  np.absolute(phi_surf_expanded/GRAV_CONST) < 1e-4 #this has precedence over the others 
    is_hot_low = np.logical_and(temp_surf >= 255,temp_bot_lapse <= 290.5, where = ~is_near_zero, out = is_hot_low)  
    is_hot_high = np.logical_and(temp_surf > 290.5, temp_bot_lapse > 290.5, where = ~is_near_zero, out =  is_hot_high) 
    is_mild_high = np.logical_and(temp_surf >=255, np.logical_and(temp_surf <= 290.5, temp_bot_lapse > 290.5, 
                                                where = ~is_near_zero, out = is_mild_high), where = ~is_near_zero, out= is_mild_high)  
    np.logical_and(temp_surf < 255, temp_bot_lapse <= 290.5, where = ~is_near_zero, out = is_cold_low) 
    test = np.logical_and(temp_surf < 255, temp_bot_lapse > 290.5, where = ~is_near_zero, out = is_cold_high)  

    #create vectorized functions 
    def psl_hot_low(ps,phi_s,T_star): 
        combo_term = ALPHA_0*phi_s/SPEC_GAS_CONST/T_star 
        return ps*np.exp(combo_term/ALPHA_0*(1-1/2*(combo_term)+1/3*(combo_term)**2))
    def psl_hot_high(ps,phi_s,T_star): 
        T_star_modified = 1/2*(290.5+T_star) 
        return ps*np.exp(phi_s/SPEC_GAS_CONST/T_star_modified)
    def psl_mild_high(ps,phi_s,T_star):
        combo_term = 290.5-T_star
        return ps*np.exp(phi_s/SPEC_GAS_CONST/T_star*(1-1/2*(combo_term)+1/3*(combo_term)**2))
    def psl_cold_low(ps,phi_s,T_star): 
        T_star_modified = 1/2*(255+T_star)
        combo_term = ALPHA_0*phi_s/SPEC_GAS_CONST/T_star_modified 
        return ps*np.exp(combo_term/ALPHA_0*(1-1/2*(combo_term)+1/3*(combo_term)**2))
    #Check this function - it may be wrong in the ncl code! 
    def psl_cold_high(ps,phi_s,T_star): 
        alpha = SPEC_GAS_CONST/phi_s*(290.5-T_star)
        T_star_modified = 1/2*(255+T_star)
        combo_term = alpha*phi_s/SPEC_GAS_CONST/T_star_modified 
        return ps*np.exp(combo_term/alpha*(1-1/2*(combo_term)+1/3*(combo_term)**2))    
    def psl_near_zero(ps,phi_s,T_star): return ps

    formulas =  [psl_near_zero,  psl_hot_low,    psl_hot_high,   psl_mild_high,  psl_cold_low,   psl_cold_high]
    cases =     [is_near_zero,   is_hot_low,     is_hot_high,    is_mild_high,   is_cold_low,    is_cold_high]

    try: 
        assert np.logical_xor.reduce(cases,axis=0).all()
    except AssertionError: 
        assert np.any(cases,axis = 0).all(), "Underlap in cases"
        assert False, "Overlap in cases"

    psl = np.full_like(pressure_surf,np.nan, dtype=)
    for where_case, formula in zip(cases,formulas): 
            psl[where_case] = formula(pressure_surf.to_numpy()[where_case],phi_surf_expanded.to_numpy()[where_case],temp_surf.to_numpy()[where_case])
    psl = pressure_surf.copy(data=psl)
    return psl 

test_pressure = psl_ecmwf(temp.isel(lev=-1,time=0), phi_surf, surf_pressure.isel(time=0), P)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/IPython/core/compilerop.py:86, in CachingCompiler.ast_parse(self, source, filename, symbol)
#      81 def ast_parse(self, source, filename='<unknown>', symbol='exec'):
#      82     """Parse code to an AST with the current compiler flags active.
#      83
#      84     Arguments are exactly the same as ast.parse (in the standard library),
#      85     and are passed to the built-in compile function."""
# ---> 86     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
# SyntaxError: invalid syntax (4154432559.py, line 62)

# %%
# %%timeit

test_pressure.to_netcdf('python_psl.nc')

default_levs = np.array([1000.0, 975.0, 950.0, 925.0, 900.0, 850.0, 800.0, 750.0, 700.0, 650.0, 600.0, 550.0, 500.0, \
             450.0, 400.0, 350.0, 300.0, 250.0, 200.0, 150.0, 100.0, 70.0, 50.0, 30.0, 20.0, 10.0 ])
# Out:
# 7.56 ms ± 982 µs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
#Interpolate to Pressure Coordinates ----------------------------------------------------------------------------------
#logging.info("Interpolating variables to pressure coordinates...")

#if current_log_level == 10: print(temp); print(surf_pressure); print(in_zsfc['PHIS']); 
hyam = in_ta.cf['hyam'] 
hybm = in_ta.cf['hybm']
hyai = in_ta.cf['hyai']
hybi = in_ta.cf['hybi']
default_levs = np.array([1000.0, 975.0, 950.0, 925.0, 900.0, 850.0, 800.0, 750.0, 700.0, 650.0, 600.0, 550.0, 500.0, \
             450.0, 400.0, 350.0, 300.0, 250.0, 200.0, 150.0, 100.0, 70.0, 50.0, 30.0, 20.0, 10.0 ])


surf_pressure = in_ps.cf['PS']
phi_surf = in_zsfc['PHIS']
temp = in_ta["T"]    
fixed_phi_sfc = in_zsfc['PHIS']  
fixed_phi_sfc.coords['lat'] = surf_pressure.coords['lat']
fixed_phi_sfc.coords['lon'] = surf_pressure.coords['lon'] 

temp_interp = gcomp.interpolation.interp_hybrid_to_pressure(temp.isel(time=0),surf_pressure.isel(time=0),hyam,hybm, 
                                                            new_levels=default_levs, 
                                                            lev_dim = 'lev', 
                                                            method='log',
                                                            extrapolate=True,
                                                            variable='temperature',
                                                            t_bot=temp.isel(lev=-1,time=0),
                                                            phi_sfc=in_zsfc['PHIS'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 20
#      17 fixed_phi_sfc.coords['lat'] = surf_pressure.coords['lat']
#      18 fixed_phi_sfc.coords['lon'] = surf_pressure.coords['lon']
# ---> 20 temp_interp = gcomp.interpolation.interp_hybrid_to_pressure(temp.isel(time=0),surf_pressure.isel(time=0),hyam,hybm,
#      21                                                             new_levels=default_levs,
#      22                                                             lev_dim = 'lev',
#      23                                                             method='log',
#      24                                                             extrapolate=True,
#      25                                                             variable='temperature',
#      26                                                             t_bot=temp.isel(lev=-1,time=0),
#      27                                                             phi_sfc=in_zsfc['PHIS'])
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/geocat/comp/interpolation.py:516, in interp_hybrid_to_pressure(data, ps, hyam, hybm, p0, new_levels, lev_dim, method, extrapolate, variable, t_bot, phi_sfc)
#     513 output = output.transpose(*dims).assign_coords(coords)
#     515 if extrapolate:
# --> 516     output = _vertical_remap_extrap(new_levels, lev_dim, data, output,
#     517                                     pressure, ps, variable, t_bot, phi_sfc)
#     519 return output
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/geocat/comp/interpolation.py:296, in _vertical_remap_extrap(new_levels, lev_dim, data, output, pressure, ps, variable, t_bot, phi_sfc)
#     292 if variable == 'temperature':
#     293     for lev in new_levels:
#     294         output.loc[dict(plev=lev)] = xr.where(
#     295             lev <= p_sfc, output.sel(plev=lev),
# --> 296             _temp_extrapolate(data, lev_dim, lev, p_sfc, ps, phi_sfc))
#     298 elif variable == 'geopotential':
#     299     for lev in new_levels:
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/geocat/comp/interpolation.py:179, in _temp_extrapolate(data, lev_dim, lev, p_sfc, ps, phi_sfc)
#     176 t0 = tstar + 0.0065 * hgt
#     177 tplat = xr.apply_ufunc(np.minimum, 298, t0, dask='parallelized')
# --> 179 tprime0 = xr.where((2000 <= hgt) & (hgt <= 2500),
#     180                    0.002 * ((2500 - hgt) * t0 + ((hgt - 2000) * tplat)),
#     181                    np.nan)
#     182 tprime0 = xr.where(2500 < hgt, tplat, tprime0)
#     184 alnp = xr.where(hgt < 2000, alpha * np.log(lev / ps),
#     185                 R_d * (tprime0 - tstar) / phi_sfc * np.log(lev / ps))
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/computation.py:1862, in where(cond, x, y, keep_attrs)
#    1859     keep_attrs = _get_keep_attrs(default=False)
#    1861 # alignment for three arguments is complicated, so don't support it yet
# -> 1862 result = apply_ufunc(
#    1863     duck_array_ops.where,
#    1864     cond,
#    1865     x,
#    1866     y,
#    1867     join="exact",
#    1868     dataset_join="exact",
#    1869     dask="allowed",
#    1870     keep_attrs=keep_attrs,
#    1871 )
#    1873 # keep the attributes of x, the second parameter, by default to
#    1874 # be consistent with the `where` method of `DataArray` and `Dataset`
#    1875 # rebuild the attrs from x at each level of the output, which could be
#    1876 # Dataset, DataArray, or Variable, and also handle coords
#    1877 if keep_attrs is True and hasattr(result, "attrs"):
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/computation.py:1197, in apply_ufunc(func, input_core_dims, output_core_dims, exclude_dims, vectorize, join, dataset_join, dataset_fill_value, keep_attrs, kwargs, dask, output_dtypes, output_sizes, meta, dask_gufunc_kwargs, *args)
#    1195 # feed DataArray apply_variable_ufunc through apply_dataarray_vfunc
#    1196 elif any(isinstance(a, DataArray) for a in args):
# -> 1197     return apply_dataarray_vfunc(
#    1198         variables_vfunc,
#    1199         *args,
#    1200         signature=signature,
#    1201         join=join,
#    1202         exclude_dims=exclude_dims,
#    1203         keep_attrs=keep_attrs,
#    1204     )
#    1205 # feed Variables directly through apply_variable_ufunc
#    1206 elif any(isinstance(a, Variable) for a in args):
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/computation.py:288, in apply_dataarray_vfunc(func, signature, join, exclude_dims, keep_attrs, *args)
#     285 from xarray.core.dataarray import DataArray
#     287 if len(args) > 1:
# --> 288     args = deep_align(
#     289         args, join=join, copy=False, exclude=exclude_dims, raise_on_invalid=False
#     290     )
#     292 objs = _all_of_type(args, DataArray)
#     294 if keep_attrs == "drop":
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/alignment.py:850, in deep_align(objects, join, copy, indexes, exclude, raise_on_invalid, fill_value)
#     847     else:
#     848         out.append(variables)
# --> 850 aligned = align(
#     851     *targets,
#     852     join=join,
#     853     copy=copy,
#     854     indexes=indexes,
#     855     exclude=exclude,
#     856     fill_value=fill_value,
#     857 )
#     859 for position, key, aligned_obj in zip(positions, keys, aligned):
#     860     if key is no_key:
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/alignment.py:787, in align(join, copy, indexes, exclude, fill_value, *objects)
#     591 """
#     592 Given any number of Dataset and/or DataArray objects, returns new
#     593 objects with aligned indexes and dimension sizes.
#    (...)
#     777
#     778 """
#     779 aligner = Aligner(
#     780     objects,
#     781     join=join,
#    (...)
#     785     fill_value=fill_value,
#     786 )
# --> 787 aligner.align()
#     788 return aligner.results
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/alignment.py:572, in Aligner.align(self)
#     570 self.find_matching_unindexed_dims()
#     571 self.assert_no_index_conflict()
# --> 572 self.align_indexes()
#     573 self.assert_unindexed_dim_sizes_equal()
#     575 if self.join == "override":
#
# File /glade/work/wukenton/conda-envs/python_correct/lib/python3.9/site-packages/xarray/core/alignment.py:417, in Aligner.align_indexes(self)
#     415 if need_reindex:
#     416     if self.join == "exact":
# --> 417         raise ValueError(
#     418             "cannot align objects with join='exact' where "
#     419             "index/labels/sizes are not equal along "
#     420             "these coordinates (dimensions): "
#     421             + ", ".join(f"{name!r} {dims!r}" for name, dims in key[0])
#     422         )
#     423     joiner = self._get_index_joiner(index_cls)
#     424     joined_index = joiner(matching_indexes)
#
# ValueError: cannot align objects with join='exact' where index/labels/sizes are not equal along these coordinates (dimensions): 'lat' ('lat',)
